# %%
import pandas as pd
import numpy as np

# %%
path_out = 'C:/임시/RData/archive/'
path_home = ''

# %%
first_debate = pd.read_csv(path_out+'us_election_2020_1st_presidential_debate.csv')

# %%
first_Biden = first_debate[first_debate.speaker=='Vice President Joe Biden']
first_Trump = first_debate[first_debate.speaker=='President Donald J. Trump']

# %%
first_Trump
# Out:
#                        speaker    minute  \
# 3    President Donald J. Trump     02:51
# 6    President Donald J. Trump     04:01
# 7    President Donald J. Trump     04:53
# 10   President Donald J. Trump     05:34
# 14   President Donald J. Trump     07:34
# ..                         ...       ...
# 777  President Donald J. Trump  01:09:17
# 780  President Donald J. Trump  01:10:07
# 783  President Donald J. Trump  01:10:41
# 785  President Donald J. Trump  01:10:47
# 787  President Donald J. Trump  01:10:49
#
#                                                   text
# 3                                   How are you doing?
# 6    Thank you very much, Chris. I will tell you ve...
# 7    And we won the election and therefore we have ...
# 10                                     Thank you, Joe.
# 14   There aren’t a hundred million people with pre...
# ..                                                 ...
# 777                             You think that’s good?
# ...

# %%
first_Trump = first_Trump.text.values.tolist()
first_Biden = first_Biden.text.values.tolist()

# %%
first_Biden
# Out:
# ['How you doing, man?',
#  'I’m well.',
#  'Well, first of all, thank you for doing this and looking forward to this, Mr. President.',
#  'The American people have a right to have a say in who the Supreme Court nominee is and that say occurs when they vote for United States Senators and when they vote for the President of United States. They’re not going to get that chance now because we’re in the middle of an election already. The election has already started. Tens of thousands of people already voted and so the thing that should happen is we should wait. We should wait and see what the outcome of this election is because that’s the only way the American people get to express their view is by who they elect as President and who they elect as Vice President.',
# ...
